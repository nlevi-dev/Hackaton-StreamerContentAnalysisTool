# %%
import huggingface

# %%
# !poetry install
# Out:
# Installing dependencies from lock file
#
# No dependencies to install or update

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from datasets import load_dataset


device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-large-v3"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    torch_dtype=torch_dtype,
    device=device,
)

dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
sample = dataset[0]["audio"]

result = pipe(sample)
print(result["text"])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[45], line 11
#       7 torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32
#       9 model_id = "openai/whisper-large-v3"
# ---> 11 model = AutoModelForSpeechSeq2Seq.from_pretrained(
#      12     model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
#      13 )
#      14 model.to(device)
#      16 processor = AutoProcessor.from_pretrained(model_id)
#
# File ~/.cache/pypoetry/virtualenvs/speech-to-text-K7lOMp4M-py3.12/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
# ...

# %%
import accelerate
accelerate.__version__
# Out:
# '1.4.0'

# %%
# !poetry show accelerate
# Out:
#  name         : accelerate
#  version      : 1.4.0
#  description  : Accelerate
#
# dependencies
#  - huggingface-hub >=0.21.0
#  - numpy >=1.17,<3.0.0
#  - packaging >=20.0
#  - psutil *
#  - pyyaml *
#  - safetensors >=0.4.3
#  - torch >=2.0.0

# %%
# !poetry env use 3.10
# Out:
# Could not find the python executable python3.10

# %%
# !poetry env info
# Out:
# Virtualenv
# Python:         3.12.3
# Implementation: CPython
# Path:           /home/andris/.cache/pypoetry/virtualenvs/speech-to-text-K7lOMp4M-py3.12
# Executable:     /home/andris/.cache/pypoetry/virtualenvs/speech-to-text-K7lOMp4M-py3.12/bin/python
# Valid:          True
#
# Base
# Platform:   linux
# OS:         posix
# Python:     3.12.3
# Path:       /usr
# Executable: /usr/bin/python3.12

# %%
# Adding Python 3.10 environment to Poetry and porting the current project

# Step 1: Set the Python version to 3.10 in the Poetry configuration
# Since there is no executable for Python 3.10, we need to specify the path to the Python 3.10 executable manually.
# Replace '/path/to/python3.10' with the actual path to your Python 3.10 executable.
# !poetry env use /usr/bin/python3.10

# Step 2: Install the dependencies in the new environment
# !poetry install

# Step 3: Verify the Python version in the Poetry environment
# !poetry run python --version

# Step 4: Verify the installed packages in the Poetry environment
# !poetry show
# Out:
# Using virtualenv: /home/andris/.cache/pypoetry/virtualenvs/speech-to-text-K7lOMp4M-py3.10
# Installing dependencies from lock file
#
# Package operations: 148 installs, 1 update, 0 removals
#
#   - Installing attrs (25.1.0): Pending...
#   - Installing rpds-py (0.23.1): Pending...
#   - Installing typing-extensions (4.12.2): Pending...
#   - Installing typing-extensions (4.12.2): Installing...
#   - Installing rpds-py (0.23.1): Pending...
#   - Installing typing-extensions (4.12.2): Installing...
#   - Installing attrs (25.1.0): Installing...
#   - Installing rpds-py (0.23.1): Pending...
#   - Installing typing-extensions (4.12.2): Installing...
#   - Installing typing-extensions (4.12.2)
#   - Installing rpds-py (0.23.1): Pending...
#   - Installing typing-extensions (4.12.2)
#   - Installing attrs (25.1.0)
#   - Installing rpds-py (0.23.1): Pending...
#   - Installing typing-extensions (4.12.2)
#   - Installing typing-extensions (4.12.2)
# ...

# %%
# !poetry lock
# Out:
# Updating dependencies
# Resolving dependencies... (8.3s)
#
# Writing lock file
